# %%
import pandas as pd
import numpy as np

# %%
file = r"C:\Users\irgpapais\Documents\Meus Projetos\Neta\nina\data\N1N@_16_07_2024_23_07_2024.CSV"
df = pd.read_csv(file, sep=';', encoding='latin-1', dtype=str)
df.replace(np.nan, '', inplace=True)

# %%
df.head(2)
# Out:
#    Linha Ano processo Codigo Processo                    Motivo Numero da OS  \
# 0  36516         2024        19539189  PARCELAMENTO MONOSUJEITO   2419539189
# 1  36517         2024        19511223  PARCELAMENTO MONOSUJEITO   2419511223
#
#   Codigo Processo/TSS    Descricao Processo/TSS Tipo Causal Mudanca Estado  \
# 0             CRD002A  PARCELAMENTO MONOSUJEITO
# 1             CRD002A  PARCELAMENTO MONOSUJEITO
#
#   Codigo TSE Descricao TSE  ...  Municipio      Bairro Toponimo  Logrdouro  \
# 0                           ...  SAO PAULO   CID LIDER      RUA  FRAIBURGO
# 1                           ...  SAO PAULO  V GERMAINE      RUA     MAXINE
#
#   Duplicidade Reincidencia Total de Rechamada Perfis Beneficiarios.1  \
# 0
# 1
#
#   Tipo manifestação Código da Interação
# 0       SOLICITAÇÃO           152565504
# 1       SOLICITAÇÃO           152521490
#
# [2 rows x 52 columns]

# %%
if len(df.columns) >= 49:
    selected = df.columns[:49]
    selected_df = df[selected]

# %%
selected_df.head(2)
# Out:
#    Linha Ano processo Codigo Processo                    Motivo Numero da OS  \
# 0  36516         2024        19539189  PARCELAMENTO MONOSUJEITO   2419539189
# 1  36517         2024        19511223  PARCELAMENTO MONOSUJEITO   2419511223
#
#   Codigo Processo/TSS    Descricao Processo/TSS Tipo Causal Mudanca Estado  \
# 0             CRD002A  PARCELAMENTO MONOSUJEITO
# 1             CRD002A  PARCELAMENTO MONOSUJEITO
#
#   Codigo TSE Descricao TSE  ... Unidade Resp Fornecimento Unidade Executante  \
# 0                           ...          DIV SAC ITAQUERA      DEP SAC LESTE
# 1                           ...          DIV SAC ITAQUERA      DEP SAC LESTE
#
#     Unidade Territorial  Municipio      Bairro Toponimo  Logrdouro  \
# 0  ATC: ATC ARTUR ALVIM  SAO PAULO   CID LIDER      RUA  FRAIBURGO
# 1  ATC: ATC ARTUR ALVIM  SAO PAULO  V GERMAINE      RUA     MAXINE
#
#   Duplicidade Reincidencia Total de Rechamada
# 0
# 1
#
# [2 rows x 49 columns]

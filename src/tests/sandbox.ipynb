# %%
import pandas as pd
import numpy as np

# %%
file = r"C:\Users\irgpapais\Documents\Meus Projetos\Neta\nina\data\N1N@_27_06_2024_04_07_2024.CSV"
df = pd.read_csv(file, sep=';', encoding='latin-1', dtype=str)
df.replace(np.nan, '', inplace=True)

# %%
df
# Out:
#        Linha Ano processo Codigo Processo  \
# 0      17876         2024        18013541
# 1      17877         2024        18008296
# 2      17878         2024     18008296.01
# 3      17879         2024        18067569
# 4      17880         2024        18069488
# ...      ...          ...             ...
# 44110   9181         2024        18279810
# 44111   9182         2024        18300201
# 44112   9183         2024        18272086
# 44113   9184         2024        18310232
# 44114   9185         2024        18247664
#
#                                                  Motivo Numero da OS  \
# 0                               MUDANÇA DE TITULARIDADE   2418013541
# 1            REFATURAMENTO COM CANCELAMENTO DAS FATURAS   2418008296
# 2                                                         2418008296
# 3      TRANSFORMAÇÃO EM CAVALETE MÚLTIPLO ATÉ 8 IMÓVEIS   2418067569
# 4                                            REATIVAÇÃO   2418069488
# ...                                                 ...          ...
# 44110                                                     2418279810
# 44111            RECLAMAÇÃO SOBRE SERVIÇOS - GRUPO ÁGUA   2418300201
# 44112                                                     2418272086
# 44113                                                     2418310232
# 44114                                                     2418247664
#
#       Codigo Processo/TSS                            Descricao Processo/TSS  \
# 0                 CRM003B                           MUDANÇA DE TITULARIDADE
# 1                 REFA01N  REFATURAMENTO COM CANCELAMENTO DE FATURAS - NOVO
# 2                    6430                       EXAME PREDIAL LEITURA/MEDIA
# 3               CRM001C04  TRANSFORMAÇÃO EM CAVALETE MÚLTIPLO ATÉ 8 IMÓVEIS
# 4               CRM002N01                                        REATIVAÇÃO
# ...                   ...                                               ...
# 44110      CRM021_SEG_VIA                             SEGUNDA VIA DE FATURA
# 44111           CRM011A10            RECLAMAÇÃO SOBRE SERVIÇOS - GRUPO ÁGUA
# 44112      CRM021_SEG_VIA                             SEGUNDA VIA DE FATURA
# 44113      CRM021_SEG_VIA                             SEGUNDA VIA DE FATURA
# 44114      CRM021_SEG_VIA                             SEGUNDA VIA DE FATURA
#
#       Tipo Causal Mudanca Estado Codigo TSE  \
# 0
# 1
# 2                                    643000
# 3
# 4
# ...                          ...        ...
# 44110
# 44111
# 44112
# 44113
# 44114
#
#                                Descricao TSE  ...  Municipio  \
# 0                                             ...  SAO PAULO
# 1                                             ...  SAO PAULO
# 2      EXAME PREDIAL LEITURA/MEDIA EXECUTADO  ...  SAO PAULO
# 3                                             ...  SAO PAULO
# 4                                             ...  SAO PAULO
# ...                                      ...  ...        ...
# 44110                                         ...  SAO PAULO
# 44111                                         ...  SAO PAULO
# 44112                                         ...  SAO PAULO
# 44113                                         ...  SAO PAULO
# 44114                                         ...  SAO PAULO
#
#                    Bairro Toponimo                 Logrdouro Duplicidade  \
# 0         UNIAO VILA NOVA      RUA                 RIO IPORA
# 1            JD MATARAZZO  AVENIDA              MILENE ELIAS
# 2            JD MATARAZZO  AVENIDA              MILENE ELIAS
# 3               V ROSARIA      RUA             ERNESTO EVANS
# 4         PQ CRUZEIRO SUL      RUA       FRANCISCO CHIARELLI
# ...                   ...      ...                       ...         ...
# 44110            ITAQUERA      RUA              SHO YOSHIOKA
# 44111  CJ INACIO MONTEIRO      RUA       CACHOEIRA JACIQUARA
# 44112            ITAQUERA  AVENIDA  DAVID DOMINGUES FERREIRA
# 44113             V SUICA      RUA               ARTE DO SOL
# 44114  CJ INACIO MONTEIRO      RUA           ARROIO TAMANDUA
#
#       Reincidencia Total de Rechamada  \
# 0
# 1
# 2
# 3
# 4
# ...            ...                ...
# 44110
# 44111
# 44112
# 44113
# 44114
#
#                                   Perfis Beneficiarios.1 Tipo manifestação  \
# 0      BPO_COBRANÇA - ENGINEERING - BPO_FATURAMENTO -...       SOLICITAÇÃO
# 1      SUPER OPERADOR COMERCIAL - BPO_COBRANÇA - ENGI...
# 2                                                               RECLAMAÇÃO
# 3      BPO_COBRANÇA - ENGINEERING - BPO_FATURAMENTO -...       SOLICITAÇÃO
# 4                                                              SOLICITAÇÃO
# ...                                                  ...               ...
# 44110                                                          SOLICITAÇÃO
# 44111                                                           RECLAMAÇÃO
# 44112                                                          SOLICITAÇÃO
# 44113                                                          SOLICITAÇÃO
# 44114                                                          SOLICITAÇÃO
#
#       Código da Interação
# 0               150209775
# 1               150205120
# 2               150205120
# 3               150293951
# 4               150292542
# ...                   ...
# 44110           150636593
# 44111           150666140
# 44112           150617282
# 44113           150682940
# 44114           150586678
#
# [44115 rows x 52 columns]
